# %%
import LDA
import pandas as pd
import MySQLdb as mdb
import collections
import datetime

def connect():
    info = {
        "host": "localhost",
        "user": "root",
        "passwd": "163613",
        "db": "news",
        "charset": "utf8"
    }
    conn = mdb.connect(**info)
    return conn

def getDocs(d):
    docs = list()
    def solve(df):
        #print df["content"]
        docs.append(df["content"])
    d.apply(solve, axis=1)
    return docs

def singleDayHandler(df):
    r = collections.defaultdict(int)
    value = df["result"]
    for i in value:
        for item in i:
            r[item[0]] += item[1]
    return pd.Series({"lda": r})

def printDF(df):
    print df

conn = connect()
sql = "select * from news"
d = pd.read_sql_query(sql, conn)
mask = ((d['time'] > datetime.datetime(2015, 1, 1)) & (d['time'] < datetime.datetime(2015, 12, 30)))
d = d[mask]

docs = getDocs(d)

lda = LDA.LDA()
lda.segment(docs)
lda.ldatrain()
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
lda.model.print_topics()
# Out:
# [(10,
#   u'0.003*pe + 0.003*neeq + 0.002*cbrc + 0.002*shipping + 0.002*soes + 0.002*leveraged + 0.002*users + 0.002*equipment + 0.002*collateral + 0.002*non-performing'),
#  (14,
#   u'0.003*survey + 0.002*telecom + 0.002*card + 0.002*target + 0.002*hu + 0.002*cards + 0.002*deng + 0.002*governor + 0.002*soccer + 0.002*regulation'),
#  (15,
#   u'0.004*apple + 0.002*crude + 0.002*soccer + 0.002*view + 0.002*delivery + 0.002*fanya + 0.002*band + 0.002*survey + 0.002*tons + 0.002*japan'),
#  (2,
#   u'0.003*deals + 0.002*deal + 0.002*agricultural + 0.002*hk + 0.002*regional + 0.002*south + 0.002*brokers + 0.002*borrowing + 0.002*pe + 0.002*ubs'),
#  (5,
#   u'0.002*options + 0.002*executives + 0.002*manipulation + 0.002*suspected + 0.002*violations + 0.002*closing + 0.001*curb + 0.001*involved + 0.001*disclosure + 0.001*slf'),
#  (19,
#   u'0.002*steel + 0.002*safe + 0.002*loan-to-deposit + 0.002*cards + 0.002*website + 0.002*software + 0.002*showing + 0.002*zhu + 0.001*road + 0.001*play'),
#  (3,
#   u'0.003*apple + 0.002*temasek + 0.002*zhongguancun + 0.002*source + 0.002*executives + 0.002*singapore + 0.002*grow + 0.002*japan + 0.002*users + 0.002*xiao'),
#  (18,
#   u'0.003*qe + 0.003*micro-sized + 0.002*zone + 0.002*islamic + 0.002*cooperation + 0.002*different + 0.002*hanergy + 0.002*tech + 0.002*base + 0.002*yuan-denominated'),
#  (13,
#   u'0.003*police + 0.002*etf + 0.002*rural + 0.002*prudent + 0.002*htsc + 0.002*dubai + 0.002*slumped + 0.002*looking + 0.002*duty + 0.002*difc'),
#  (4,
#   u'0.002*soared + 0.002*non-tradable + 0.002*lu + 0.002*hsbc + 0.002*lock-up + 0.002*tradable + 0.002*volatile + 0.002*huishan + 0.002*scheme + 0.002*year-on-year')]

# %%
for i in range(20):
    lda.model.print_topic(i)

# %%
lda.model.print_topic(8)
# Out:
# u'0.004*options + 0.002*nuclear + 0.002*court + 0.002*south + 0.002*lme + 0.002*flows + 0.002*applications + 0.002*lock-up + 0.002*case + 0.002*clear'

# %%
lda.model.
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %%
reload(Segment)
t = Segment.segment(str)

# %%
model = ldamodel.LdaModel(t, id2word=dic, num_topics=100)
# Out:
# [[(0, 2),
#   (1, 4),
#   (2, 1),
#   (3, 3),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 1),
#   (9, 2),
#   (10, 3),
#   (11, 1),
#   (12, 2),
#   (13, 2),
#   (14, 1),
#   (15, 1),
#   (16, 1),
#   (17, 1),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 3),
#   (22, 1),
#   (23, 2),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 6),
#   (28, 3),
#   (29, 1),
#   (30, 3),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 4),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 2),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 3),
#   (47, 2),
#   (48, 1),
#   (49, 2),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 4),
#   (56, 3),
#   (57, 2),
#   (58, 3),
#   (59, 1),
#   (60, 1)],
#  [(1, 5),
#   (3, 4),
#   (4, 1),
#   (5, 1),
#   (6, 5),
#   (8, 1),
#   (9, 2),
#   (10, 2),
#   (12, 3),
#   (15, 6),
#   (17, 1),
#   (18, 1),
#   (20, 1),
#   (23, 4),
#   (24, 1),
#   (25, 2),
#   (27, 9),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (32, 1),
#   (34, 1),
#   (35, 10),
#   (36, 2),
#   (38, 4),
#   (39, 1),
#   (41, 1),
#   (43, 1),
#   (45, 1),
#   (46, 2),
#   (47, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 4),
#   (56, 1),
#   (60, 2),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 9),
#   (65, 1),
#   (66, 1),
#   (67, 4),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 1),
#   (72, 2),
#   (73, 3),
#   (74, 1),
#   (75, 3),
#   (76, 2),
#   (77, 2),
#   (78, 1),
#   (79, 1),
#   (80, 3),
#   (81, 1),
#   (82, 2),
#   (83, 2),
#   (84, 1),
#   (85, 2),
#   (86, 2),
#   (87, 2),
#   (88, 2),
#   (89, 2),
#   (90, 5),
#   (91, 2),
#   (92, 1),
#   (93, 1),
#   (94, 1)],
#  [(0, 6),
#   (1, 14),
#   (2, 1),
#   (3, 7),
#   (5, 6),
#   (7, 1),
#   (9, 4),
#   (10, 2),
#   (11, 2),
#   (13, 4),
#   (14, 1),
#   (15, 5),
#   (16, 1),
#   (18, 3),
#   (19, 1),
#   (21, 3),
#   (22, 2),
#   (23, 8),
#   (26, 1),
#   (27, 3),
#   (28, 3),
#   (29, 2),
#   (33, 4),
#   (35, 6),
#   (36, 1),
#   (37, 1),
#   (38, 5),
#   (39, 2),
#   (40, 2),
#   (42, 1),
#   (43, 1),
#   (44, 3),
#   (45, 1),
#   (46, 3),
#   (47, 4),
#   (48, 1),
#   (49, 5),
#   (50, 1),
#   (54, 2),
#   (55, 17),
#   (56, 1),
#   (58, 3),
#   (61, 2),
#   (63, 1),
#   (64, 1),
#   (66, 1),
#   (67, 4),
#   (68, 1),
#   (69, 5),
#   (70, 2),
#   (71, 1),
#   (72, 3),
#   (74, 1),
#   (75, 1),
#   (76, 3),
#   (81, 1),
#   (84, 4),
#   (86, 1),
#   (88, 1),
#   (92, 1),
#   (93, 1),
#   (95, 2),
#   (96, 2),
#   (97, 2),
#   (98, 2),
#   (99, 2),
#   (100, 2),
#   (101, 2),
#   (102, 2),
#   (103, 2),
#   (104, 2),
#   (105, 3),
#   (106, 2),
#   (107, 1),
#   (108, 2),
#   (109, 2),
#   (110, 2),
#   (111, 2),
#   (112, 1),
#   (113, 1),
#   (114, 2),
#   (115, 1),
#   (116, 2),
#   (117, 2),
#   (118, 2),
#   (119, 2),
#   (120, 2),
#   (121, 2),
#   (122, 2),
#   (123, 2),
#   (124, 2),
#   (125, 1)],
#  [(18, 1), (28, 1), (47, 1), (53, 1), (54, 1), (59, 1), (111, 1)],
#  [(0, 1),
#   (1, 1),
#   (3, 2),
#   (5, 2),
#   (9, 1),
#   (13, 1),
#   (15, 1),
#   (19, 1),
#   (21, 6),
#   (23, 3),
#   (28, 1),
#   (29, 1),
#   (31, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (40, 1),
#   (42, 3),
#   (46, 1),
#   (47, 2),
#   (48, 1),
#   (49, 2),
#   (55, 1),
#   (56, 2),
#   (62, 1),
#   (65, 1),
#   (72, 1),
#   (78, 1),
#   (79, 2),
#   (94, 1),
#   (97, 1),
#   (106, 1),
#   (107, 1),
#   (112, 1),
#   (113, 1),
#   (115, 1),
#   (125, 1),
#   (126, 2),
#   (127, 2),
#   (128, 3)]]

# %%
model = ldamodel.LdaModel(, id2word=dictionary, num_topics=100)
