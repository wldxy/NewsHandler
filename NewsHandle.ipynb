# %%
import MySQLdb as mdb
import pandas as pd

# %%
info = {
    "host": "localhost",
    "user": "root",
    "passwd": "163613",
    "db": "news",
    "charset": "utf8"
}
conn = mdb.connect(**info)

# %%
sql = "select * from news limit 5;"
d = pd.read_sql_query(sql, conn)

# %%
print d
# Out:
#                                                  url  \
# 0  http://www.chinadaily.com.cn/business/2014-11/...
# 1  http://www.chinadaily.com.cn/business/2014-11/...
# 2  http://www.chinadaily.com.cn/business/2014-11/...
# 3  http://www.chinadaily.com.cn/business/2014-11/...
# 4  http://www.chinadaily.com.cn/business/2014-11/...
#
#                                                title                time  \
# 0  Landmark Shanghai-HK stock link to debut on Mo... 2014-11-17 09:22:00
# 1  Income tax exemption fuels Shanghai-HK stock c... 2014-11-17 09:40:00
# 2                Shares fall as stock connect debuts 2014-11-17 09:46:00
# 3              Sydney to launch RMB clearing service 2014-11-17 15:05:00
# 4           Global investors push Shanghai bourse up 2014-11-17 15:08:00
#
#                                              content
# 0  SHANGHAI - A trading link that will let Hong K...
# 1  BEIJING - Income tax exemptions for investors ...
# 2  \nHong Kong Exchanges and Clearing Ltd Chairma...
# 3  CANBERRA - China and Australia signed a deal M...
# 4  Shanghai Stock Exchange, China's benchmark equ...

# %%
str = []
def segment(df):
    global str
    str.append(df["content"])

# %%
d.apply(segment, axis = 1)
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %%
reload(Segment)
t = Segment.segment(str)

# %%
model = ldamodel.LdaModel(t, id2word=dic, num_topics=100)
# Out:
# [[(0, 2),
#   (1, 4),
#   (2, 1),
#   (3, 3),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 1),
#   (9, 2),
#   (10, 3),
#   (11, 1),
#   (12, 2),
#   (13, 2),
#   (14, 1),
#   (15, 1),
#   (16, 1),
#   (17, 1),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 3),
#   (22, 1),
#   (23, 2),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 6),
#   (28, 3),
#   (29, 1),
#   (30, 3),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 4),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 2),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 3),
#   (47, 2),
#   (48, 1),
#   (49, 2),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 4),
#   (56, 3),
#   (57, 2),
#   (58, 3),
#   (59, 1),
#   (60, 1)],
#  [(1, 5),
#   (3, 4),
#   (4, 1),
#   (5, 1),
#   (6, 5),
#   (8, 1),
#   (9, 2),
#   (10, 2),
#   (12, 3),
#   (15, 6),
#   (17, 1),
#   (18, 1),
#   (20, 1),
#   (23, 4),
#   (24, 1),
#   (25, 2),
#   (27, 9),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (32, 1),
#   (34, 1),
#   (35, 10),
#   (36, 2),
#   (38, 4),
#   (39, 1),
#   (41, 1),
#   (43, 1),
#   (45, 1),
#   (46, 2),
#   (47, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 4),
#   (56, 1),
#   (60, 2),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 9),
#   (65, 1),
#   (66, 1),
#   (67, 4),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 1),
#   (72, 2),
#   (73, 3),
#   (74, 1),
#   (75, 3),
#   (76, 2),
#   (77, 2),
#   (78, 1),
#   (79, 1),
#   (80, 3),
#   (81, 1),
#   (82, 2),
#   (83, 2),
#   (84, 1),
#   (85, 2),
#   (86, 2),
#   (87, 2),
#   (88, 2),
#   (89, 2),
#   (90, 5),
#   (91, 2),
#   (92, 1),
#   (93, 1),
#   (94, 1)],
#  [(0, 6),
#   (1, 14),
#   (2, 1),
#   (3, 7),
#   (5, 6),
#   (7, 1),
#   (9, 4),
#   (10, 2),
#   (11, 2),
#   (13, 4),
#   (14, 1),
#   (15, 5),
#   (16, 1),
#   (18, 3),
#   (19, 1),
#   (21, 3),
#   (22, 2),
#   (23, 8),
#   (26, 1),
#   (27, 3),
#   (28, 3),
#   (29, 2),
#   (33, 4),
#   (35, 6),
#   (36, 1),
#   (37, 1),
#   (38, 5),
#   (39, 2),
#   (40, 2),
#   (42, 1),
#   (43, 1),
#   (44, 3),
#   (45, 1),
#   (46, 3),
#   (47, 4),
#   (48, 1),
#   (49, 5),
#   (50, 1),
#   (54, 2),
#   (55, 17),
#   (56, 1),
#   (58, 3),
#   (61, 2),
#   (63, 1),
#   (64, 1),
#   (66, 1),
#   (67, 4),
#   (68, 1),
#   (69, 5),
#   (70, 2),
#   (71, 1),
#   (72, 3),
#   (74, 1),
#   (75, 1),
#   (76, 3),
#   (81, 1),
#   (84, 4),
#   (86, 1),
#   (88, 1),
#   (92, 1),
#   (93, 1),
#   (95, 2),
#   (96, 2),
#   (97, 2),
#   (98, 2),
#   (99, 2),
#   (100, 2),
#   (101, 2),
#   (102, 2),
#   (103, 2),
#   (104, 2),
#   (105, 3),
#   (106, 2),
#   (107, 1),
#   (108, 2),
#   (109, 2),
#   (110, 2),
#   (111, 2),
#   (112, 1),
#   (113, 1),
#   (114, 2),
#   (115, 1),
#   (116, 2),
#   (117, 2),
#   (118, 2),
#   (119, 2),
#   (120, 2),
#   (121, 2),
#   (122, 2),
#   (123, 2),
#   (124, 2),
#   (125, 1)],
#  [(18, 1), (28, 1), (47, 1), (53, 1), (54, 1), (59, 1), (111, 1)],
#  [(0, 1),
#   (1, 1),
#   (3, 2),
#   (5, 2),
#   (9, 1),
#   (13, 1),
#   (15, 1),
#   (19, 1),
#   (21, 6),
#   (23, 3),
#   (28, 1),
#   (29, 1),
#   (31, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (40, 1),
#   (42, 3),
#   (46, 1),
#   (47, 2),
#   (48, 1),
#   (49, 2),
#   (55, 1),
#   (56, 2),
#   (62, 1),
#   (65, 1),
#   (72, 1),
#   (78, 1),
#   (79, 2),
#   (94, 1),
#   (97, 1),
#   (106, 1),
#   (107, 1),
#   (112, 1),
#   (113, 1),
#   (115, 1),
#   (125, 1),
#   (126, 2),
#   (127, 2),
#   (128, 3)]]

# %%
model = ldamodel.LdaModel(, id2word=dictionary, num_topics=100)
